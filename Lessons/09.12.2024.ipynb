# %%
pip install pandas

# %%
import pandas as pd

# %%
st = {2:1, 3:3, 4:10, 5:4}

# %%
st[5]
# Out:
# 4

# %%
data = {'apples':[3, 2, 0, 1], 'oranges':[0, 3, 7, 2]}
data
# Out:
# {'apples': [3, 2, 0, 1], 'oranges': [0, 3, 7, 2]}

# %%
table = pd.DataFrame(data)
table
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
table2 = pd.DataFrame(data, index=['April', 'May', 'June', 'Jule'])
table2
# Out:
#        apples  oranges
# April       3        0
# May         2        3
# June        0        7
# Jule        1        2

# %%
table['apples']
# Out:
# 0    3
# 1    2
# 2    0
# 3    1
# Name: apples, dtype: int64

# %%
table['oranges']
# Out:
# 0    0
# 1    3
# 2    7
# 3    2
# Name: oranges, dtype: int64

# %%
table.loc[1]
# Out:
# apples     2
# oranges    3
# Name: 1, dtype: int64

# %%
df = pd.read_csv('/content/ign.csv')
df
# Out:
#        Unnamed: 0 score_phrase  \
# 0               0      Amazing
# 1               1      Amazing
# 2               2        Great
# 3               3        Great
# 4               4        Great
# ...           ...          ...
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# ...                                                  ...
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# ...

# %%
df.to_csv('new.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
# 6           6        Awful                                Double Dragon: Neon
# 7           7      Amazing                                       Guild Wars 2
# 8           8        Awful                                Double Dragon: Neon
# 9           9         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# ...

# %%
df.tail(10)
# Out:
#        Unnamed: 0 score_phrase  \
# 18615       18615      Amazing
# 18616       18616         Good
# 18617       18617        Great
# 18618       18618      Amazing
# 18619       18619         Good
# 18620       18620         Good
# 18621       18621      Amazing
# 18622       18622     Mediocre
# 18623       18623  Masterpiece
# 18624       18624  Masterpiece
#
#                                                    title  \
# 18615                                  Zero Time Dilemma
# 18616  Batman: The Telltale Series -- Episode 1: Real...
# 18617                                               Abzu
# 18618                                          Starbound
# 18619                                    Human Fall Flat
# 18620                          Tokyo Mirage Sessions #FE
# 18621                  LEGO Star Wars: The Force Awakens
# 18622            Star Ocean: Integrity and Faithlessness
# 18623                                             Inside
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18625 entries, 0 to 18624
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      18625 non-null  int64
#  1   score_phrase    18625 non-null  object
#  2   title           18625 non-null  object
#  3   url             18625 non-null  object
#  4   platform        18625 non-null  object
#  5   score           18625 non-null  float64
#  6   genre           18589 non-null  object
#  7   editors_choice  18625 non-null  object
#  8   release_year    18625 non-null  int64
#  9   release_month   18625 non-null  int64
#  10  release_day     18625 non-null  int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.6+ MB

# %%
df.shape
# Out:
# (18625, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'score_phrase', 'title', 'url', 'platform', 'score',
#        'genre', 'editors_choice', 'release_year', 'release_month',
#        'release_day'],
#       dtype='object')

# %%
df2 = df[['score_phrase', 'title', 'platform', 'score', 'genre', 'editors_choice', 'release_year']]
df2
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# ...            ...                                                ...
# 18620         Good                          Tokyo Mirage Sessions #FE
# 18621      Amazing                  LEGO Star Wars: The Force Awakens
# 18622     Mediocre            Star Ocean: Integrity and Faithlessness
# 18623  Masterpiece                                             Inside
# 18624  Masterpiece                                             Inside
#
#                platform  score              genre editors_choice  release_year
# ...

# %%
df2.isnull()
# Out:
#        score_phrase  title  platform  score  genre  editors_choice  \
# 0             False  False     False  False  False           False
# 1             False  False     False  False  False           False
# 2             False  False     False  False  False           False
# 3             False  False     False  False  False           False
# 4             False  False     False  False  False           False
# ...             ...    ...       ...    ...    ...             ...
# 18620         False  False     False  False  False           False
# 18621         False  False     False  False  False           False
# 18622         False  False     False  False  False           False
# 18623         False  False     False  False  False           False
# 18624         False  False     False  False  False           False
#
#        release_year
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# ...

# %%
df2.isnull().sum()
# Out:
# score_phrase       0
# title              0
# platform           0
# score              0
# genre             36
# editors_choice     0
# release_year       0
# dtype: int64

# %%
df3 = df2.dropna()
df3
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2            Great                               Splice: Tree of Life
# 3            Great                                             NHL 13
# 4            Great                                             NHL 13
# ...            ...                                                ...
# 18620         Good                          Tokyo Mirage Sessions #FE
# 18621      Amazing                  LEGO Star Wars: The Force Awakens
# 18622     Mediocre            Star Ocean: Integrity and Faithlessness
# 18623  Masterpiece                                             Inside
# 18624  Masterpiece                                             Inside
#
#                platform  score              genre editors_choice  release_year
# ...

# %%
df3.isnull().sum()
# Out:
# score_phrase      0
# title             0
# platform          0
# score             0
# genre             0
# editors_choice    0
# release_year      0
# dtype: int64

# %%
import numpy as np

arr = np.array([18, 23, 15, 41])
arr.mean()
# Out:
# 24.25

# %%
df3['genre']
# Out:
# 0               Platformer
# 1               Platformer
# 2                   Puzzle
# 3                   Sports
# 4                   Sports
#                ...
# 18620                  RPG
# 18621    Action, Adventure
# 18622                  RPG
# 18623            Adventure
# 18624            Adventure
# Name: genre, Length: 18589, dtype: object

# %%
df3['genre'].describe()
# Out:
# count      18589
# unique       112
# top       Action
# freq        3797
# Name: genre, dtype: object

# %%
df3['genre'].value_counts().head(5)
# Out:
# genre
# Action       3797
# Sports       1916
# Shooter      1610
# Racing       1228
# Adventure    1175
# Name: count, dtype: int64

# %%
df4 = df3.fillna('Action')

# %%
df4.isnull().sum()
# Out:
# score_phrase      0
# title             0
# platform          0
# score             0
# genre             0
# editors_choice    0
# release_year      0
# dtype: int64

# %%
df4.head(5)
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#            platform  score       genre editors_choice  release_year
# 0  PlayStation Vita    9.0  Platformer              Y          2012
# 1  PlayStation Vita    9.0  Platformer              Y          2012
# 2              iPad    8.5      Puzzle              N          2012
# 3          Xbox 360    8.5      Sports              N          2012
# 4     PlayStation 3    8.5      Sports              N          2012

# %%
df4[df4['score'] >= 9]
# Out:
#       score_phrase                                              title  \
# 0          Amazing                            LittleBigPlanet PS Vita
# 1          Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 7          Amazing                                       Guild Wars 2
# 13         Amazing                                  Mark of the Ninja
# 14         Amazing                                  Mark of the Ninja
# ...            ...                                                ...
# 18615      Amazing                                  Zero Time Dilemma
# 18618      Amazing                                          Starbound
# 18621      Amazing                  LEGO Star Wars: The Force Awakens
# 18623  Masterpiece                                             Inside
# 18624  Masterpiece                                             Inside
#
#                platform  score              genre editors_choice  release_year
# ...

# %%
pd.set_option('display.max_rows', 500)

# %%
df4[(df4['score'] >= 8) & (df4['release_year'] == 2016)].head(100)
# Out:
#       score_phrase                                              title  \
# 18275        Great                                    FAST Racing Neo
# 18349      Amazing                                    Darkest Dungeon
# 18350      Amazing                                    Darkest Dungeon
# 18352  Masterpiece                                        The Witness
# 18353  Masterpiece                                        The Witness
# 18354  Masterpiece                                        The Witness
# 18355        Great               Plants vs. Zombies: Garden Warfare 2
# 18356        Great               Plants vs. Zombies: Garden Warfare 2
# 18357        Great      Pillar of Eternity: The White March - Part II
# 18358      Amazing                      Fire Emblem Fates: Revelation
# 18379        Great                       Homeworld: Deserts of Kharak
# 18386        Great                                      Rocket League
# ...

# %%
df4['score']
# Out:
# 0         9.0
# 1         9.0
# 2         8.5
# 3         8.5
# 4         8.5
#          ...
# 18620     7.6
# 18621     9.0
# 18622     5.8
# 18623    10.0
# 18624    10.0
# Name: score, Length: 18589, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(df4['score'])
# Out:
# (array([  43.,  227.,  491.,  896., 1611., 2098., 3574., 4777., 3930.,
#          942.]),
#  array([ 0.5 ,  1.45,  2.4 ,  3.35,  4.3 ,  5.25,  6.2 ,  7.15,  8.1 ,
#          9.05, 10.  ]),
#  <BarContainer object of 10 artists>)

# %%
df4['score'].value_counts()
# Out:
# score
# 8.0     1751
# 7.0     1563
# 7.5     1081
# 8.5     1026
# 6.0      992
# 9.0      916
# 6.5      771
# 5.0      766
# 5.5      527
# 4.0      516
# 7.8      464
# 7.9      371
# 4.5      368
# 8.8      320
# 6.8      314
# 8.4      311
# 8.2      301
# 3.0      296
# 8.3      280
# 7.7      250
# 7.2      231
# 9.5      230
# 7.4      226
# 8.7      225
# 7.3      220
# 8.9      212
# 3.5      207
# 6.9      185
# 7.6      183
# 8.6      181
# 9.3      160
# 8.1      158
# 6.7      158
# 2.0      150
# 9.2      146
# 6.2      144
# 9.1      141
# 7.1      136
# 5.8      133
# 9.4      110
# 5.9      109
# 6.4      108
# 6.3      106
# 4.8      100
# 2.5      100
# 5.2       93
# 4.9       91
# 6.6       89
# 5.3       81
# 6.1       73
# 5.7       70
# 5.1       65
# 5.6       62
# 10.0      55
# 5.4       51
# 9.6       47
# 3.8       42
# 4.3       39
# 4.2       38
# 4.7       35
# 4.6       34
# 1.0       33
# 9.7       28
# 4.1       27
# 3.3       22
# 1.5       22
# ...

# %%
df4['score'].describe()
# Out:
# count    18589.000000
# mean         6.950853
# std          1.712078
# min          0.500000
# 25%          6.000000
# 50%          7.300000
# 75%          8.200000
# max         10.000000
# Name: score, dtype: float64

# %%
df4['score'].plot(kind='box')
# Out:
# <Axes: >

# %%
df5 = df4[df4['score'] > 2.8]

# %%
df5['score'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/
